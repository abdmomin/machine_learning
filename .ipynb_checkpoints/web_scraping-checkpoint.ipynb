# %%
import requests

years = list(range(1991, 2022))

for year in years:
    url = f'https://www.basketball-reference.com/awards/awards_{year}.html'
    data = requests.get(url)
    
    with open(f'NBA/{year}.html', 'w+') as f:
        f.write(data.text)

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
dfs = []

for year in years:
    with open(f'NBA/{year}.html') as f:
        page = f.read()
    soup = BeautifulSoup(page, 'html.parser')
    soup.find('tr', class_='over_header').decompose()
    mvp_table = soup.find(id='mvp')
    mvp = pd.read_html(str(mvp_table))[0]
    mvp['Year'] = year
    
    dfs.append(mvp)

# %%
mvps = pd.concat(dfs)

# %%
mvps.head()
# Out:
#   Rank           Player  Age   Tm  First  Pts Won  Pts Max  Share   G    MP  \
# 0    1   Michael Jordan   27  CHI   77.0    891.0      960  0.928  82  37.0
# 1    2    Magic Johnson   31  LAL   10.0    497.0      960  0.518  79  37.1
# 2    3   David Robinson   25  SAS    6.0    476.0      960  0.496  82  37.7
# 3    4  Charles Barkley   27  PHI    2.0    222.0      960  0.231  67  37.3
# 4    5      Karl Malone   27  UTA    0.0    142.0      960  0.148  82  40.3
#
#    ...   TRB   AST  STL  BLK    FG%    3P%    FT%    WS  WS/48  Year
# 0  ...   6.0   5.5  2.7  1.0  0.539  0.312  0.851  20.3  0.321  1991
# 1  ...   7.0  12.5  1.3  0.2  0.477  0.320  0.906  15.4  0.251  1991
# 2  ...  13.0   2.5  1.5  3.9  0.552  0.143  0.762  17.0  0.264  1991
# 3  ...  10.1   4.2  1.6  0.5  0.570  0.284  0.722  13.4  0.258  1991
# 4  ...  11.8   3.3  1.1  1.0  0.527  0.286  0.770  15.5  0.225  1991
#
# [5 rows x 21 columns]

# %%
mvps.shape
# Out:
# (474, 21)

# %%
mvps.to_csv('mvps.csv')

# %%
mvps.tail()
# Out:
#      index Rank             Player  Age   Tm  First  Pts Won  Pts Max  Share  \
# 469     10   11  Russell Westbrook   32  WAS    0.0      5.0     1010  0.005
# 470     11   12        Ben Simmons   24  PHI    0.0      3.0     1010  0.003
# 471     12  13T       James Harden   31  TOT    0.0      1.0     1010  0.001
# 472     13  13T       LeBron James   36  LAL    0.0      1.0     1010  0.001
# 473     14  13T      Kawhi Leonard   29  LAC    0.0      1.0     1010  0.001
#
#       G  ...   TRB   AST  STL  BLK    FG%    3P%    FT%   WS  WS/48  Year
# 469  65  ...  11.5  11.7  1.4  0.4  0.439  0.315  0.656  3.7  0.075  2021
# 470  58  ...   7.2   6.9  1.6  0.6  0.557  0.300  0.613  6.0  0.153  2021
# 471  44  ...   7.9  10.8  1.2  0.8  0.466  0.362  0.861  7.0  0.208  2021
# 472  45  ...   7.7   7.8  1.1  0.6  0.513  0.365  0.698  5.6  0.179  2021
# 473  52  ...   6.5   5.2  1.6  0.4  0.512  0.398  0.885  8.8  0.238  2021
#
# [5 rows x 22 columns]

# %%
url_20 = 'https://www.basketball-reference.com/leagues/NBA_2020_per_game.html'

data = requests.get(url_20)
with open('player/2020.html', 'w+') as f:
    f.write(data.text)

# %%
from selenium import webdriver

# %%
## xattr -d com.apple.quarantine chromedriver --> run on terminal

# %%
driver = webdriver.Chrome(executable_path='/Users/abdullahalmomin/Documents/PROJECTS/chromedriver')
# Out:
# /var/folders/b0/2gd4pmxn5g793y37y_qkjqkr0000gn/T/ipykernel_13043/1644612873.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='/Users/abdullahalmomin/Downloads/chromedriver')

# %%
import time

# %%
for year in years:
    url = f'https://www.basketball-reference.com/leagues/NBA_{year}_per_game.html'
    
    driver.get(url)
    driver.execute_script('window.scrollTo(1, 10000)')
    time.sleep(2)
    
    html = driver.page_source
    with open(f'player/{year}.html', 'w+') as f:
        f.write(html)

# %%
df = []

for year in years:
    with open(f'player/{year}.html') as f:
        page = f.read()
    soup = BeautifulSoup(page, 'html.parser')
    soup.find('tr', class_='thead').decompose()
    player_table = soup.find(id='per_game_stats')
    player = pd.read_html(str(player_table))[0]
    player['Year'] = year
    
    df.append(player)

# %%
df[0].head()
# Out:
#   Rk              Player Pos Age   Tm   G  GS    MP   FG   FGA  ...  ORB  DRB  \
# 0  1      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7  ...  0.6  1.4
# 1  2  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1  ...  0.5  1.3
# 2  3          Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1  ...  2.1  3.2
# 3  4       Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5  ...  0.9  3.0
# 4  5        Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7  ...  1.7  3.1
#
#    TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0  2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1  1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2  5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3  3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4  4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
#
# [5 rows x 31 columns]

# %%
players = pd.concat(df)

# %%
players.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG   FGA  ...  ORB  DRB  \
# 725  536    Delon Wright  PG  28  SAC  27   8  25.8  3.9   8.3  ...  1.0  2.9
# 726  537  Thaddeus Young  PF  32  CHI  68  23  24.3  5.4   9.7  ...  2.5  3.8
# 727  538      Trae Young  PG  22  ATL  63  63  33.7  7.7  17.7  ...  0.6  3.3
# 728  539     Cody Zeller   C  28  CHO  48  21  20.9  3.8   6.8  ...  2.5  4.4
# 729  540     Ivica Zubac   C  23  LAC  72  33  22.3  3.6   5.5  ...  2.6  4.6
#
#      TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 725  3.9  3.6  1.6  0.4  1.3  1.1  10.0  2021
# 726  6.2  4.3  1.1  0.6  2.0  2.2  12.1  2021
# 727  3.9  9.4  0.8  0.2  4.1  1.8  25.3  2021
# 728  6.8  1.8  0.6  0.4  1.1  2.5   9.4  2021
# 729  7.2  1.3  0.3  0.9  1.1  2.6   9.0  2021
#
# [5 rows x 31 columns]

# %%
players.shape
# Out:
# (18044, 31)

# %%
players.reset_index(inplace=True)

# %%
players.to_csv('players.csv')

# %%
for year in years:
    url_team = f'https://www.basketball-reference.com/leagues/NBA_{year}_standings.html'
    data = requests.get(url_team)
    
    with open(f'team/{year}.html', 'w+') as f:
        f.write(data.text)

# %%
df = []
for year in years:
    with open(f'team/{year}.html') as f:
        page = f.read()
        
    soup = BeautifulSoup(page, 'html.parser')
    soup.find('tr', class_='thead').decompose()
    team_table = soup.find(id='divs_standings_E')
    team = pd.read_html(str(team_table))[0]
    team['Year'] = year
    team['Team'] = team['Eastern Conference']
    del team['Eastern Conference']
    df.append(team)
    
    soup = BeautifulSoup(page, 'html.parser')
    soup.find('tr', class_='thead').decompose()
    team_table = soup.find(id='divs_standings_W')
    team = pd.read_html(str(team_table))[0]
    team['Year'] = year
    team['Team'] = team['Western Conference']
    del team['Western Conference']
    df.append(team)

# %%
teams = pd.concat(df)

# %%
teams.tail()
# Out:
#      W   L  W/L%    GB   PS/G   PA/G    SRS  Year                  Team
# 13  42  30  .583     —  112.4  110.2   2.26  2021     Dallas Mavericks*
# 14  38  34  .528   4.0  113.3  112.3   1.07  2021    Memphis Grizzlies*
# 15  33  39  .458   9.0  111.1  112.8  -1.58  2021     San Antonio Spurs
# 16  31  41  .431  11.0  114.6  114.9  -0.20  2021  New Orleans Pelicans
# 17  17  55  .236  25.0  108.8  116.7  -7.50  2021       Houston Rockets

# %%
teams.shape
# Out:
# (1033, 9)

# %%
teams.reset_index(inplace=True)

# %%
teams.to_csv('teams.csv')
